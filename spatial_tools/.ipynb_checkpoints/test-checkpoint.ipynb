# %%
import plotly.express as px
from matplotlib import image

# %%
import scanpy as sc
import anndata as ad

# %%
_h5ad_data = ad.read_h5ad('/Users/jmzhang/workspace/mygithub/SpatialTools/spatial_tools/data_set/level7.h5ad')

# %%
adata.obs
# Out:
#           n_genes leiden
# L7_599       1724      5
# L7_600       1708      5
# L7_640       1699      5
# L7_641       1447      5
# L7_642       1818      5
# ...           ...    ...
# L7_18856      467      8
# L7_18857      726      0
# L7_18858      400      0
# L7_18859      195      8
# L7_18860      243      8
#
# [14851 rows x 2 columns]

# %%
import pandas as pd

# %%
_other_data = pd.read_csv('data_set/L7_heAuto_RCTD.xls', sep='\t')

# %%
data_others
# Out:
#                  spot_class           first_type  \
# L7_599      doublet_certain  Neuroendocrine cell
# L7_600      doublet_certain  Neuroendocrine cell
# L7_640               reject       Erythroid cell
# L7_641      doublet_certain       Allantois cell
# L7_642    doublet_uncertain       Erythroid cell
# ...                     ...                  ...
# L7_18856  doublet_uncertain       Erythroid cell
# L7_18857            singlet     Endothelial cell
# L7_18858             reject       Allantois cell
# L7_18859             reject       Allantois cell
# L7_18860             reject     Endothelial cell
#
#                              second_type  first_class  second_class  \
# L7_599                    Erythroid cell        False         False
# L7_600                    Erythroid cell        False         False
# L7_640    Oligodendrocyte precursor cell        False         False
# L7_641                    Erythroid cell        False         False
# ...

# %%
data['conv_all']
# Out:
# L2_11793     True
# L2_11979     True
# L2_11980     True
# L2_11981     True
# L2_11982     True
#              ...
# L2_337692    True
# L2_337699    True
# L2_337706    True
# L2_337712    True
# L2_337728    True
# Name: conv_all, Length: 148671, dtype: bool
